# %% [markdown]
# <a href="https://colab.research.google.com/github/I-Lokesh-Vardhan/AENEXZ-INTERNSHIP/blob/main/Aenexz_task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a800df2f-4694-4562-aa3d-06c60cb355cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a800df2f-4694-4562-aa3d-06c60cb355cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d amith1707/covid-epidemic-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/amith1707/covid-epidemic-dataset
# License(s): CC0-1.0
# ...
# 100% 109M/109M [00:01<00:00, 113MB/s]

# %%
# !unzip covid-epidemic-dataset.zip
# Out:
# Archive:  covid-epidemic-dataset.zip
#   inflating: LICENSE.txt
#   inflating: README.md
#   inflating: data/features/covid_features.csv
#   inflating: data/full/covid_full.csv/covid_processed.csv
#   inflating: data/splits/covid_test.csv
#   inflating: data/splits/covid_train.csv
#   inflating: data/splits/covid_val.csv
#   inflating: data/subsets/covid_classification.csv
#   inflating: data/subsets/covid_forecast.csv
#   inflating: data/subsets/covid_policy_analysis.csv
#   inflating: data/subsets/covid_regression.csv
#   inflating: metadata/metadata.json
#   inflating: notebook/demo.ipynb

# %%
import os

for root, dirs, files in os.walk('/content'):
    for file in files:
        if file.endswith('.csv'):
            print(os.path.join(root, file))
# Out:
# /content/data/subsets/covid_policy_analysis.csv
# /content/data/subsets/covid_forecast.csv
# /content/data/subsets/covid_classification.csv
# /content/data/subsets/covid_regression.csv
# /content/data/features/covid_features.csv
# /content/data/full/covid_full.csv/covid_processed.csv
# /content/data/splits/covid_test.csv
# /content/data/splits/covid_train.csv
# /content/data/splits/covid_val.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/california_housing_test.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/data/splits/covid_train.csv')
df.head()
# Out:
#        country      continent  income_group  population density_category  \
# 0    Argentina  South America  upper_middle    45000000              low
# 1       Turkey           Asia  upper_middle    84000000           medium
# 2  Country_037           Asia           low    55438797           medium
# 3  Country_077  South America  lower_middle    51258223              low
# 4      Germany         Europe          high    83000000           medium
#
#          date  year  month  day  dayofweek  ...  reporting_quality  \
# 0  2020-01-22  2020      1   22          2  ...                1.0
# 1  2020-01-22  2020      1   22          2  ...                1.0
# 2  2020-01-22  2020      1   22          2  ...                1.0
# 3  2020-01-22  2020      1   22          2  ...                1.0
# 4  2020-01-22  2020      1   22          2  ...                1.0
#
#   cum_cases_pct_pop  cum_deaths_pct_pop  policy_effectiveness  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             country      continent  income_group  population density_category  \
# 0         Argentina  South America  upper_middle    45000000              low
# 1            Turkey           Asia  upper_middle    84000000           medium
# 2       Country_037           Asia           low    55438797           medium
# 3       Country_077  South America  lower_middle    51258223              low
# 4           Germany         Europe          high    83000000           medium
# ...             ...            ...           ...         ...              ...
# 167995  Country_108         Africa  upper_middle    71495374        very_high
# 167996  Country_028           Asia          high    65969883           medium
# 167997  Country_038           Asia  upper_middle    70380543             high
# 167998  Country_069           Asia  upper_middle    66908761        very_high
# 167999  Country_014           Asia  lower_middle     7828432           medium
#
# ...

# %%
df.shape
# Out:
# (168000, 79)

# %%
df.isnull().sum()
# Out:
# country                      0
# continent                    0
# income_group                 0
# population                   0
# density_category             0
#                          ...
# target_new_cases_14d         0
# target_new_deaths_14d        0
# target_rt_7d             39899
# target_trend_7d              0
# target_in_wave               0
# Length: 79, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# df.dropna(inplace=True) --> for dropping rows
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df["target_trend_7d"] = df["target_trend_7d"].fillna(df["target_trend_7d"].mode()[0])
df
# Out:
#             country      continent  income_group  population density_category  \
# 0         Argentina  South America  upper_middle    45000000              low
# 1            Turkey           Asia  upper_middle    84000000           medium
# 2       Country_037           Asia           low    55438797           medium
# 3       Country_077  South America  lower_middle    51258223              low
# 4           Germany         Europe          high    83000000           medium
# ...             ...            ...           ...         ...              ...
# 167995  Country_108         Africa  upper_middle    71495374        very_high
# 167996  Country_028           Asia          high    65969883           medium
# 167997  Country_038           Asia  upper_middle    70380543             high
# 167998  Country_069           Asia  upper_middle    66908761        very_high
# 167999  Country_014           Asia  lower_middle     7828432           medium
#
# ...

# %%
df.dtypes
# Out:
# country                   object
# continent                 object
# income_group              object
# population                 int64
# density_category          object
#                           ...
# target_new_cases_14d     float64
# target_new_deaths_14d    float64
# target_rt_7d             float64
# target_trend_7d            int64
# target_in_wave             int64
# Length: 79, dtype: object

# %%
df.rename(columns = {"dayofweek":"days_of_week"},inplace = True)
df
# Out:
#             country      continent  income_group  population density_category  \
# 0         Argentina  South America  upper_middle    45000000              low
# 1            Turkey           Asia  upper_middle    84000000           medium
# 2       Country_037           Asia           low    55438797           medium
# 3       Country_077  South America  lower_middle    51258223              low
# 4           Germany         Europe          high    83000000           medium
# ...             ...            ...           ...         ...              ...
# 167995  Country_108         Africa  upper_middle    71495374        very_high
# 167996  Country_028           Asia          high    65969883           medium
# 167997  Country_038           Asia  upper_middle    70380543             high
# 167998  Country_069           Asia  upper_middle    66908761        very_high
# 167999  Country_014           Asia  lower_middle     7828432           medium
#
# ...

# %%
df=df[['country','income_group','population','density_category','policy_effectiveness']]
df
# Out:
#             country  income_group  population density_category  \
# 0         Argentina  upper_middle    45000000              low
# 1            Turkey  upper_middle    84000000           medium
# 2       Country_037           low    55438797           medium
# 3       Country_077  lower_middle    51258223              low
# 4           Germany          high    83000000           medium
# ...             ...           ...         ...              ...
# 167995  Country_108  upper_middle    71495374        very_high
# 167996  Country_028          high    65969883           medium
# 167997  Country_038  upper_middle    70380543             high
# 167998  Country_069  upper_middle    66908761        very_high
# 167999  Country_014  lower_middle     7828432           medium
#
#         policy_effectiveness
# 0                   0.524898
# 1                   0.524898
# 2                   0.524898
# 3                   0.524898
# 4                   0.524898
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['population'])
plt.show()
